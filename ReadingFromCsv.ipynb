# %% [markdown]
# Loading the required library.

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Read the player.csv and team.csv file as a dataframe.

# %%
Players <- read.table("Player.csv")
Teams <- read.table("Team.csv")

# %% [markdown]
# -------------------------------------Structure of the Players dataframe-----------------------------------------------

# %%
Players
# Out:
#       player_name              player_api_id overall_rating gk_attributes
# 1     Patryk Rachwal,18        2625          63             153
# 2     Diego Mainz              2752          72              53
# 3     Jose Dorado              2768          75             128
# 4     Ignacio Gonzalez         2770          74             148
# 5     Alberto Rey              2790          73             144
# 6     Javier Jimenez           2796          69             340
# 7     Pablo Hernandez          2802          82             146
# 8     Ruben Perez              2805          76             141
# 9     Ivan Perez               2857          72             143
# 10    Vicente Sanchez          2862          76             146
# 11    Gregory Lacombe          2907          68             135
# 12    Ugur Inceman             2973          72             147
# 13    David Rivas Rodriguez    2977          82             104
# 14    Jorge Molina             2983          75             139
# ...

# %% [markdown]
# 1) Which are the top 10 players by overall rating?

# %% [markdown]
# Dataframe which orders the players by their overall_rating and returns the top 10.

# %%
Overall_Rating<-(head(arrange(Players,desc(overall_rating))$player_name, n=10))
as.data.frame(Overall_Rating)
# Out:
#    Overall_Rating
# 1  Lionel Messi
# 2  Gianluigi Buffon
# 3  Wayne Rooney
# 4  Cristiano Ronaldo
# 5  Xavi Hernandez
# 6  Gregory Coupet
# 7  Thierry Henry
# 8  John Terry
# 9  Iker Casillas
# 10 Alessandro Nesta

# %% [markdown]
# 2) Which are the top 10 goalkeepers by sum of gk attributes?

# %% [markdown]
# Dataframe which orders the players by their gk_attributes and returns the top 10.

# %%
Gk_Attributes<-(head(arrange(Players,desc(gk_attributes))$player_name, n=10))
as.data.frame(Gk_Attributes)
# Out:
#    Gk_Attributes
# 1  Gianluigi Buffon
# 2  Gregory Coupet
# 3  Petr Cech
# 4  Iker Casillas
# 5  Manuel Neuer
# 6  Julio Cesar
# 7  Sebastian Frey
# 8  Edwin van der Sar
# 9  David De Gea
# 10 Pepe Reina

# %% [markdown]
# 3) Which are the top 10 players by number of appearances (with any team they played with)?

# %% [markdown]
# Dataframe which orders the players by their gk_attributes and returns the top 10.

# %%
Number_Appearances <-(head(arrange(Players,desc(num_appearances))$player_name, n=10))
as.data.frame(Number_Appearances)
# Out:
#    Number_Appearances
# 1  Steve Mandanda
# 2  Stephane Ruffier
# 3  Gorka Iraizoz Moreno
# 4  Samir Handanovic
# 5  Hugo Lloris
# 6  Tim Howard
# 7  Joe Hart
# 8  Cedric Carrasso
# 9  Daniel Congre
# 10 Moussa Sissoko

# %% [markdown]
# 4) Which are the top 10 players by number of leagues they played in?

# %% [markdown]
# Dataframe which orders the players by the number of leagues they played and returns the top 10.

# %%
Number_Leagues <-(head(arrange(Players,desc(num_leagues))$player_name, n=10))
as.data.frame(Number_Leagues)
# Out:
#    Number_Leagues
# 1  Gelson Fernandes
# 2  Ricky van Wolfswinkel
# 3  Filip Djuricic
# 4  Radamel Falcao
# 5  Jonathan De Guzman
# 6  Almen Abdi
# 7  Ibrahim Afellay
# 8  Edson Braafheid
# 9  Eljero Elia
# 10 Danijel Pranjic

# %% [markdown]
# -------------------------------------------Structure of the Teams dataframe-------------------------------------------

# %%
Teams
# Out:
#     team_long_name           team_api_id buildUpPlay_attributes
# 1   Ruch Chorzów             1601        139
# 2   Oud-Heverlee Leuven      1773        153
# 3   Jagiellonia Białystok    1957        158
# 4   S.C. Olhanense           2033        147
# 5   Lech Poznań              2182        176
# 6   P. Warszawa              2183         NA
# 7   Cracovia                 2186        125
# 8   Évian Thonon Gaillard FC 4087        156
# 9   US Boulogne Cote D'Opale 4170         NA
# 10  Novara                   6269        179
# 11  KAS Eupen                6351         NA
# 12  GFC Ajaccio              6391        153
# 13  FC Paços de Ferreira     6403        142
# 14  PEC Zwolle               6413        137
# 15  Leixões SC               6421         NA
# 16  Go Ahead Eagles          6433        160
# 17  AC Bellinzona            6493         NA
# 18  FC Penafiel              6547        147
# 19  FC Dordrecht             6631        134
# ...

# %% [markdown]
# 5) Which are the top 10 teams by sum of build up play attributes?

# %% [markdown]
# Dataframe which orders the teams by their BuildUpAttributes and returns the top 10.

# %%
BuildUpAttributes <-(head(arrange(Teams,desc(buildUpPlay_attributes))$team_long_name, n=10))
as.data.frame(BuildUpAttributes)
# Out:
#    BuildUpAttributes
# 1  Torino
# 2  Udinese
# 3  Fortuna Düsseldorf
# 4  Podbeskidzie Bielsko-Biała
# 5  Korona Kielce
# 6  Widzew Łódź
# 7  Widzew Łódź
# 8  Carpi
# 9  FC Nantes
# 10 Sassuolo

# %% [markdown]
# 6) Which are the top 10 teams by sum of chance creation attributes?

# %% [markdown]
# Dataframe which orders the teams by their chanceCreationAttributes and returns the top 10.

# %%
chanceCreationAttributes <-(head(arrange(Teams,desc(chanceCreation_attributes))$team_long_name, n=10))
as.data.frame(chanceCreationAttributes)
# Out:
#    chanceCreationAttributes
# 1  Lazio
# 2  SV Werder Bremen
# 3  Napoli
# 4  Bayer 04 Leverkusen
# 5  Burnley
# 6  Cardiff City
# 7  Manchester City
# 8  Aberdeen
# 9  Rangers
# 10 Tottenham Hotspur

# %% [markdown]
# 7) Which are the top 10 teams by sum of defense attributes?

# %% [markdown]
# Dataframe which orders the teams by their defenceAttributes and returns the top 10.

# %%
defenceAttributes <-(head(arrange(Teams,desc(defence_attributes))$team_long_name, n=10))
as.data.frame(defenceAttributes)
# Out:
#    defenceAttributes
# 1  Jagiellonia Białystok
# 2  SC Bastia
# 3  Zagłębie Lubin
# 4  Leicester City
# 5  Cardiff City
# 6  1. FC Kaiserslautern
# 7  Southampton
# 8  AS Nancy-Lorraine
# 9  Blackpool
# 10 Stade Brestois 29

# %% [markdown]
# 8) Which are the top 10 teams by number of scored goals?

# %% [markdown]
# Dataframe which orders the teams by the number of goals they scored and returns the top 10.

# %%
Goals <-(head(arrange(Teams,desc(goals))$team_long_name, n=10))
as.data.frame(Goals)
# Out:
#    Goals
# 1  FC Barcelona
# 2  Real Madrid CF
# 3  Celtic
# 4  FC Bayern Munich
# 5  PSV
# 6  Ajax
# 7  FC Basel
# 8  Manchester City
# 9  Chelsea
# 10 Manchester United
